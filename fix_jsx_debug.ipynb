# %%
# Read the problematic JSX file and print lines around the reported error
file_path = "c:/Users/jeffe/Downloads/Brane/frontend/src/pages/SocialPage.js"
with open(file_path, encoding="utf-8") as f:
    lines = f.readlines()
for i in range(1250, 1270):
    print(f"{i+1}: {lines[i].rstrip()}")
